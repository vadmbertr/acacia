# %%
import scanpy as sc
import anndata
import MultiMAP

sc.settings.set_figure_params(dpi=80)

# %%
#rna = sc.read('rna.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/rna.h5ad')
#atac_peaks = sc.read('atac-peaks.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/atac-peaks.h5ad')
atac_genes = sc.read('atac-genes.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/atac-genes.h5ad')
# Out:
# WARNING: Failed to open the url with default certificates, trying with certifi.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1541                     type = value.upper()
# -> 1542             fp, retrlen = fw.retrfile(file, type)
#    1543             headers = ""
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in retrfile(self, file, type)
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in ntransfercmd(self, cmd, rest)
#     360             conn = socket.create_connection((host, port), self.timeout,
# --> 361                                             source_address=self.source_address)
#     362             try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/Desktop/Post-doc/Luke/projects/acacia/results/2210_3MB_4multimap/multimap3.7/lib/python3.7/site-packages/scanpy/readwrite.py in _download(url, path)
#     952         try:
# --> 953             open_url = urlopen(req)
#     954         except URLError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1552             exc = URLError('ftp error: %r' % exp)
# -> 1553             raise exc.with_traceback(sys.exc_info()[2])
#    1554
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1541                     type = value.upper()
# -> 1542             fp, retrlen = fw.retrfile(file, type)
#    1543             headers = ""
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in retrfile(self, file, type)
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in ntransfercmd(self, cmd, rest)
#     360             conn = socket.create_connection((host, port), self.timeout,
# --> 361                                             source_address=self.source_address)
#     362             try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# URLError: <urlopen error ftp error: TimeoutError(60, 'Operation timed out')>
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1541                     type = value.upper()
# -> 1542             fp, retrlen = fw.retrfile(file, type)
#    1543             headers = ""
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in retrfile(self, file, type)
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in ntransfercmd(self, cmd, rest)
#     360             conn = socket.create_connection((host, port), self.timeout,
# --> 361                                             source_address=self.source_address)
#     362             try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /var/folders/qg/fygltshx1_dc1b44fz9gbly40000gn/T/ipykernel_70006/3772391364.py in <module>
#       1 #rna = sc.read('rna.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/rna.h5ad')
#       2 #atac_peaks = sc.read('atac-peaks.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/atac-peaks.h5ad')
# ----> 3 atac_genes = sc.read('atac-genes.h5ad', backup_url='ftp://ngs.sanger.ac.uk/production/teichmann/MultiMAP/atac-genes.h5ad')
#
# ~/Desktop/Post-doc/Luke/projects/acacia/results/2210_3MB_4multimap/multimap3.7/lib/python3.7/site-packages/scanpy/readwrite.py in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     120             cache=cache,
#     121             cache_compression=cache_compression,
# --> 122             **kwargs,
#     123         )
#     124     # generate filename and read to dict
#
# ~/Desktop/Post-doc/Luke/projects/acacia/results/2210_3MB_4multimap/multimap3.7/lib/python3.7/site-packages/scanpy/readwrite.py in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     714     else:
#     715         ext = is_valid_filename(filename, return_ext=True)
# --> 716     is_present = _check_datafile_present_and_download(filename, backup_url=backup_url)
#     717     if not is_present:
#     718         logg.debug(f'... did not find original file {filename}')
#
# ~/Desktop/Post-doc/Luke/projects/acacia/results/2210_3MB_4multimap/multimap3.7/lib/python3.7/site-packages/scanpy/readwrite.py in _check_datafile_present_and_download(path, backup_url)
#    1000         path.parent.mkdir(parents=True)
#    1001
# -> 1002     _download(backup_url, path)
#    1003     return True
#    1004
#
# ~/Desktop/Post-doc/Luke/projects/acacia/results/2210_3MB_4multimap/multimap3.7/lib/python3.7/site-packages/scanpy/readwrite.py in _download(url, path)
#     960             from ssl import create_default_context
#     961
# --> 962             open_url = urlopen(req, context=create_default_context(cafile=where()))
#     963
#     964         with open_url as resp:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1551         except ftplib.all_errors as exp:
#    1552             exc = URLError('ftp error: %r' % exp)
# -> 1553             raise exc.with_traceback(sys.exc_info()[2])
#    1554
#    1555     def connect_ftp(self, user, passwd, host, port, dirs, timeout):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in ftp_open(self, req)
#    1540                    value in ('a', 'A', 'i', 'I', 'd', 'D'):
#    1541                     type = value.upper()
# -> 1542             fp, retrlen = fw.retrfile(file, type)
#    1543             headers = ""
#    1544             mtype = mimetypes.guess_type(req.full_url)[0]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in retrfile(self, file, type)
#    2404             try:
#    2405                 cmd = 'RETR ' + file
# -> 2406                 conn, retrlen = self.ftp.ntransfercmd(cmd)
#    2407             except ftplib.error_perm as reason:
#    2408                 if str(reason)[:3] != '550':
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ftplib.py in ntransfercmd(self, cmd, rest)
#     359             host, port = self.makepasv()
#     360             conn = socket.create_connection((host, port), self.timeout,
# --> 361                                             source_address=self.source_address)
#     362             try:
#     363                 if rest is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
#     727         try:
# --> 728             raise err
#     729         finally:
#     730             # Break explicitly a reference cycle
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# URLError: <urlopen error ftp error: TimeoutError(60, 'Operation timed out')>

# %%
MultiMAP.TFIDF_LSI(atac_peaks)
atac_genes.obsm['X_lsi'] = atac_peaks.obsm['X_lsi'].copy()

rna_pca = rna.copy()
sc.pp.scale(rna_pca)
sc.pp.pca(rna_pca)
rna.obsm['X_pca'] = rna_pca.obsm['X_pca'].copy()

# %%
adata = MultiMAP.Integration([rna, atac_genes], ['X_pca', 'X_lsi'])

# %%
sc.pl.embedding(adata, 'X_multimap', color=['source','cell_type'])
